# %% [markdown]
# <img width="160" align="right" alt="scilab-logo" src="https://pbs.twimg.com/profile_images/738653831903477760/ahNtcvQC.jpg"/>
# # Sample Scilab Notebook
#
# This is a demo notebook for the Scilab language.
#
# For learning about Scilab, please check [this tutorial](https://www.scilab.org/content/view/full/849).
#
# For learning about jupyter notebooks, please check [this other tutorial](http://nbviewer.jupyter.org/github/jupyter/notebook/blob/master/docs/source/examples/Notebook/Notebook%20Basics.ipynb).

# %%
2+2
# Out:
# 4.

# %%
x = -%pi:0.01:%pi;
plot(x, sin(x))

# %% [markdown]
# ## Try it!
#
# Type and execute Scilab commands in the cell below.
